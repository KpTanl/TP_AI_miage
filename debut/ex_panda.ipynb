# %% [markdown]
# 1 导入 Créer un dataframe df en important le fichier pokemon.csv (disponible sur Moodle)
# avec la colonne Name comme index . Afficher le data frame. Afficher les informations1
# générales sur ce dataframe .2

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("pokemon.csv")

print("----dataframe info---")
df.info()
print("---head---")
df.head()
# Out:
# ----dataframe info---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB
# ---head---
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# ...

# %%
# 2
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
# 3
df['Type 2']
df.loc[:,'Type 2']
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4         NaN
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 800, dtype: object

# %%
# 4
df['Type 2'] =  df['Type 2'].fillna('')
df['Type 2'].head(10)
# Out:
# 0    Poison
# 1    Poison
# 2    Poison
# 3    Poison
# 4
# 5
# 6    Flying
# 7    Dragon
# 8    Flying
# 9
# Name: Type 2, dtype: object

# %%
# 5
df = df.drop(columns = ['#','Sp. Atk','Sp. Def'])
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Speed  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49     45
# 1                Ivysaur  Grass  Poison    405  60      62       63     60
# 2               Venusaur  Grass  Poison    525  80      82       83     80
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123     80
# 4             Charmander   Fire            309  39      52       43     65
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 3           1      False
# 4           1      False

# %%
# 6 
df.loc[df['Name'] == 'Bulbasaur',['Type 1', 'Type 2']]
# 注意 这里非索引的时候
# Out:
#   Type 1  Type 2
# 0  Grass  Poison

# %%
# 7 
df.iloc[-5:,:2]
# Out:
#                     Name   Type 1
# 795              Diancie     Rock
# 796  DiancieMega Diancie     Rock
# 797  HoopaHoopa Confined  Psychic
# 798   HoopaHoopa Unbound  Psychic
# 799            Volcanion     Fire

# %%
# 8
df[(df['Type 1'] == 'Grass') & (df['Legendary'] == True)]
# Out:
#                   Name Type 1    Type 2  Total   HP  Attack  Defense  Speed  \
# 550  ShayminLand Forme  Grass              600  100     100      100    100
# 551   ShayminSky Forme  Grass    Flying    600  100     103       75    127
# 701           Virizion  Grass  Fighting    580   91      90       72    108
#
#      Generation  Legendary
# 550           4       True
# 551           4       True
# 701           5       True

# %%
#9
df[['Total','HP','Attack','Defense']].describe()
# Out:
#            Total          HP      Attack     Defense
# count  800.00000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500
# std    119.96304   25.534669   32.457366   31.183501
# min    180.00000    1.000000    5.000000    5.000000
# 25%    330.00000   50.000000   55.000000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000

# %%
# 10
df[df['HP'] == df['HP'].max()]
# Out:
#         Name  Type 1 Type 2  Total   HP  Attack  Defense  Speed  Generation  \
# 261  Blissey  Normal           540  255      10       10     55           2
#
#      Legendary
# 261      False

# %%
# 11
df.sort_values('Speed',ascending = False).head(3)
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 431      DeoxysSpeed Forme  Psychic            600  50      95       90
# 315                Ninjask      Bug  Flying    456  61      90       45
# 71   AlakazamMega Alakazam  Psychic            590  55      50       65
#
#      Speed  Generation  Legendary
# 431    180           3       True
# 315    160           3      False
# 71     150           1      False

# %%
# 12
df['Legendary'].value_counts()
# Out:
# Legendary
# False    735
# True      65
# Name: count, dtype: int64

# %%
# 13
lengendary = df.groupby('Legendary')
lengendary.head(5)
# 14
lengendary[['Total','HP','Attack','Defense','Speed']].mean()
# Out:
#                 Total         HP      Attack    Defense       Speed
# Legendary
# False      417.213605  67.182313   75.669388  71.559184   65.455782
# True       637.384615  92.738462  116.676923  99.661538  100.184615

# %%
# 15
import matplotlib.pyplot as pl
type_counts = df['Type 1'].value_counts()
pl.bar(type_counts.index, type_counts.values)
pl.xticks(rotation=45) # 把横坐标文字旋转45度，防止重叠
pl.show()
